# %%
import pandas as pd

# %%
df = pd.read_csv('kpmi_data-2.csv')
# Out:
# /var/folders/mb/7kg509493q3gkj2g2ktj03200000gn/T/ipykernel_13128/256345281.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('kpmi_data-2.csv')

# %%
df.shape
# Out:
# (21846, 154)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21846 entries, 0 to 21845
# Columns: 154 entries, jobtitle to satisfied
# dtypes: int64(151), object(3)
# memory usage: 25.7+ MB

# %%
df.head()
# Out:
#      jobtitle            jobfield  q1  q2  q3  q4  q5  q6  q7  q8  ...  \
# 0         NaN                 NaN   1   0   0   0   0   1   1   0  ...
# 1  HR manager  Staff and training   1   0   0   1   1   1   1   0  ...
# 2  HR manager  Staff and training   0   0   1   0   0   1   1   0  ...
# 3  HR manager  Staff and training   0   0   1   1   0   1   1   0  ...
# 4  HR manager  Staff and training   0   0   0   0   0   1   1   0  ...
#
#    scale_e  scale_i  scale_s  scale_n  scale_t  scale_f  scale_j  scale_p  \
# 0        5       26       25       12       24        8       27       10
# 1       16       22       17       16       23       11       22       15
# 2       28        6       14       18       20       16       20       15
# 3       28       10       22       10       16       14       22       12
# 4       24       10       16       17       13       23       31        3
#
#    psychotype  satisfied
# 0        ISTJ          0
# 1        ISTJ          1
# ...

# %% [markdown]
# ### Missing Values

# %%
df.isnull().sum()
# Out:
# jobtitle      9225
# jobfield      8347
# q1               0
# q2               0
# q3               0
#               ...
# scale_f          0
# scale_j          0
# scale_p          0
# psychotype       0
# satisfied        0
# Length: 154, dtype: int64

# %% [markdown]
# ### Summary Statistics (numerical)

# %%
df.describe()
# Out:
#                  q1            q2            q3            q4            q5  \
# count  21846.000000  21846.000000  21846.000000  21846.000000  21846.000000
# mean       0.389591      0.265861      0.660624      0.306784      0.259773
# std        0.487669      0.441801      0.473508      0.461169      0.438520
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      1.000000      0.000000      0.000000
# 75%        1.000000      1.000000      1.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  q6            q7            q8            q9           q10  \
# count  21846.000000  21846.000000  21846.000000  21846.000000  21846.000000
# mean       0.715646      0.794013      0.255791      0.495514      0.291770
# ...

# %% [markdown]
# ### Summary Statistics (Categorical)

# %%
df.describe(include=['object'])
# Out:
#        jobtitle             jobfield psychotype
# count     12621                13499      21846
# unique       68                   12         16
# top     Student  Communication sales       ESTJ
# freq       1428                 2203       6464

# %% [markdown]
# ### Unique values per column

# %%
for col in df.columns: 
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# jobtitle: 68 unique values
# jobfield: 12 unique values
# q1: 2 unique values
# q2: 2 unique values
# q3: 2 unique values
# q4: 2 unique values
# q5: 2 unique values
# q6: 2 unique values
# q7: 2 unique values
# q8: 2 unique values
# q9: 2 unique values
# q10: 2 unique values
# q11: 2 unique values
# q12: 2 unique values
# q13: 2 unique values
# q14: 2 unique values
# q15: 2 unique values
# q16: 2 unique values
# q17: 2 unique values
# q18: 2 unique values
# q19: 2 unique values
# q20: 2 unique values
# q21: 2 unique values
# q22: 2 unique values
# q23: 2 unique values
# q24: 2 unique values
# q25: 2 unique values
# q26: 2 unique values
# q27: 2 unique values
# q28: 2 unique values
# q29: 2 unique values
# q30: 2 unique values
# q31: 2 unique values
# q32: 2 unique values
# q33: 2 unique values
# q34: 2 unique values
# q35: 2 unique values
# q36: 2 unique values
# q37: 2 unique values
# q38: 2 unique values
# q39: 2 unique values
# q40: 2 unique values
# q41: 2 unique values
# ...

# %% [markdown]
# ### Distribution of categorical columns

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"Value counts for {col}:")
    print(df[col].value_counts())
    print("\n")
# Out:
# Value counts for jobtitle:
# jobtitle
# Student                          1428
# Head (trade mediation)           1296
# Account Manager                   693
# Sales Manager                     588
# HR manager                        480
#                                  ...
# Copywriter                         21
# Начальник службы безопасности      19
# Head (research area)                6
# Regional Manager                    6
# Bodyguard                           4
# Name: count, Length: 68, dtype: int64
#
#
# Value counts for jobfield:
# jobfield
# Communication sales          2203
# Head of the organization     2136
# Specialists                  1729
# Students                     1551
# Finance                      1276
# Staff and training           1163
# Department head               946
# Advertising and marketing     721
# IT                            674
# Administration                582
# Top management                411
# Security                      107
# ...

# %% [markdown]
# ### dropping null values of both jobtitle and jobfield columns

# %%
df = df.dropna(subset=['jobtitle', 'jobfield'], how='all')

# %%
df.shape
# Out:
# (13499, 154)

# %%
df.isnull().sum()
# Out:
# jobtitle      878
# jobfield        0
# q1              0
# q2              0
# q3              0
#              ...
# scale_f         0
# scale_j         0
# scale_p         0
# psychotype      0
# satisfied       0
# Length: 154, dtype: int64

# %% [markdown]
# ### dropping survey response columns

# %%
df = df.drop(columns=[col for col in df.columns if col.startswith("q")])

# %%
df.shape
# Out:
# (13499, 12)

# %%
df.head()
# Out:
#      jobtitle            jobfield  scale_e  scale_i  scale_s  scale_n  \
# 1  HR manager  Staff and training       16       22       17       16
# 2  HR manager  Staff and training       28        6       14       18
# 3  HR manager  Staff and training       28       10       22       10
# 4  HR manager  Staff and training       24       10       16       17
# 5  HR manager  Staff and training       25       12       17       13
#
#    scale_t  scale_f  scale_j  scale_p psychotype  satisfied
# 1       23       11       22       15       ISTJ          1
# 2       20       16       20       15       ENTJ          0
# 3       16       14       22       12       ESTJ          1
# 4       13       23       31        3       ENFJ          0
# 5       23       11       10       25       ESTP          1

# %%
df.isnull().sum()
# Out:
# jobtitle      878
# jobfield        0
# scale_e         0
# scale_i         0
# scale_s         0
# scale_n         0
# scale_t         0
# scale_f         0
# scale_j         0
# scale_p         0
# psychotype      0
# satisfied       0
# dtype: int64

# %%
df.to_csv('cleaned_kpmi_data.csv', index=False)
