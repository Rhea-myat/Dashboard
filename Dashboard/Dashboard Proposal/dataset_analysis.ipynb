# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_kpmi_data.csv')
df.head()
# Out:
#      jobtitle            jobfield  scale_e  scale_i  scale_s  scale_n  \
# 0  HR manager  Staff and training       16       22       17       16
# 1  HR manager  Staff and training       28        6       14       18
# 2  HR manager  Staff and training       28       10       22       10
# 3  HR manager  Staff and training       24       10       16       17
# 4  HR manager  Staff and training       25       12       17       13
#
#    scale_t  scale_f  scale_j  scale_p psychotype  satisfied
# 0       23       11       22       15       ISTJ          1
# 1       20       16       20       15       ENTJ          0
# 2       16       14       22       12       ESTJ          1
# 3       13       23       31        3       ENFJ          0
# 4       23       11       10       25       ESTP          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13499 entries, 0 to 13498
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   jobtitle    12621 non-null  object
#  1   jobfield    13499 non-null  object
#  2   scale_e     13499 non-null  int64
#  3   scale_i     13499 non-null  int64
#  4   scale_s     13499 non-null  int64
#  5   scale_n     13499 non-null  int64
#  6   scale_t     13499 non-null  int64
#  7   scale_f     13499 non-null  int64
#  8   scale_j     13499 non-null  int64
#  9   scale_p     13499 non-null  int64
#  10  psychotype  13499 non-null  object
#  11  satisfied   13499 non-null  int64
# dtypes: int64(9), object(3)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (13499, 12)

# %%
df.describe(include='all')
# Out:
#        jobtitle             jobfield       scale_e       scale_i  \
# count     12621                13499  13499.000000  13499.000000
# unique       68                   12           NaN           NaN
# top     Student  Communication sales           NaN           NaN
# freq       1428                 2203           NaN           NaN
# mean        NaN                  NaN     20.391733     15.872213
# std         NaN                  NaN      6.550919      6.513572
# min         NaN                  NaN      0.000000      0.000000
# 25%         NaN                  NaN     16.000000     11.000000
# 50%         NaN                  NaN     21.000000     16.000000
# 75%         NaN                  NaN     25.000000     21.000000
# max         NaN                  NaN     35.000000     35.000000
#
#              scale_s       scale_n       scale_t       scale_f       scale_j  \
# count   13499.000000  13499.000000  13499.000000  13499.000000  13499.000000
# ...

# %%
df.isnull().sum()
# Out:
# jobtitle      878
# jobfield        0
# scale_e         0
# scale_i         0
# scale_s         0
# scale_n         0
# scale_t         0
# scale_f         0
# scale_j         0
# scale_p         0
# psychotype      0
# satisfied       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['jobtitle', 'jobfield', 'scale_e', 'scale_i', 'scale_s', 'scale_n',
#        'scale_t', 'scale_f', 'scale_j', 'scale_p', 'psychotype', 'satisfied'],
#       dtype='object')

# %%
df.jobfield.unique()
# Out:
# array(['Staff and training', 'Department head', 'Top management', 'IT',
#        'Advertising and marketing', 'Communication sales', 'Specialists',
#        'Administration', 'Finance', 'Students',
#        'Head of the organization', 'Security'], dtype=object)

# %%
df.jobfield.value_counts()
# Out:
# jobfield
# Communication sales          2203
# Head of the organization     2136
# Specialists                  1729
# Students                     1551
# Finance                      1276
# Staff and training           1163
# Department head               946
# Advertising and marketing     721
# IT                            674
# Administration                582
# Top management                411
# Security                      107
# Name: count, dtype: int64

# %%
df.jobtitle.unique()
# Out:
# array(['HR manager', 'IT director', 'IT manager', 'PR manager',
#        'Sales Agent (real estate insurance)', 'System administrator',
#        'Administrator of the trading floor', 'Analyst',
#        'Financial analyst', 'System Architect', 'Graduate student',
#        'Foreman (manufacturing)', 'Brand manager', 'Accountant',
#        'Businessman', 'General director', 'Chief Accountant', 'Designer',
#        'Marketing director', 'HR Director', 'Director of Development',
#        'Advertising Director', 'Journalist', 'Cashier',
#        'Commercial Director', 'Consultant', 'Copywriter',
#        'Manager of logistick', 'Wholesale Manager', 'Sales Manager',
#        'Account Manager', 'Advertising Manager', 'Sales manager',
#        'Head of Department', 'Head of Commercial Department',
#        'Начальник службы безопасности', 'Head of Financial Department',
#        'Head of the legal department',
#        'Operator (electrical appliances mechanisms)', 'Office Manager',
# ...

# %%
df.jobtitle.value_counts()
# Out:
# jobtitle
# Student                          1428
# Head (trade mediation)           1296
# Account Manager                   693
# Sales Manager                     588
# HR manager                        480
#                                  ...
# Copywriter                         21
# Начальник службы безопасности      19
# Head (research area)                6
# Regional Manager                    6
# Bodyguard                           4
# Name: count, Length: 68, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
df['psychotype'].hist(bins=30)
plt.show()
